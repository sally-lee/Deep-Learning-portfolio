# %% [markdown]
# #**Forward Propagation in a Deep Network**

# %% [markdown]
# - - -

# %% [markdown]
# ##**학습목표**

# %% [markdown]
# - - -

# %% [markdown]
# 정방향 전파를 어떻게 수행하는지 살펴보자.

# %% [markdown]
# ##**단일학습 데이터 x에 대한 Forward propagation**

# %% [markdown]
# - - -

# %% [markdown]
# ![123.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###**<심층 신경망의 1층>**

# %% [markdown]
# - - -

# %% [markdown]
# ![1234.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *  $z^{[1]}$ = $W^{[1]}$$a^{[0]}$+$b^{[1]}$
#  $\rightarrow$$W^{[1]}$과 $b^{[1]}$은 층 1에서 활성화에 영향을 주는 파라미터
#
# * $a^{[1]}$= $g^{[1]}(z^{[1]}$) $\rightarrow$ 1층에 대한 활성화 계산

# %% [markdown]
# ###**<심층 신경망의 2층>**

# %% [markdown]
# - - -

# %% [markdown]
# ![12345.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *  $z^{[2]}$ = $W^{[2]}$$a^{[1]}$+$b^{[2]}$  $\rightarrow$$W^{[2]}$과 +$b^{[2]}$은 층 2에서 활성화에 영향을 주는 파라미터
#
# * $a^{[2]}$= $g^{[2]}(z^{[2]}$)$\rightarrow$ 2층에 대한 활성화 계산

# %% [markdown]
# ###**<심층 신경망의 3층>**

# %% [markdown]
# - - -

# %% [markdown]
# ![123456.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *  $z^{[3]}$ = $W^{[3]}$$a^{[2]}$+$b^{[3]}$ $\rightarrow$$W^{[3]}$과 $b^{[3]}$은 층 2에서 활성화에 영향을 주는 파라미터
#
# * $a^{[3]}$= $g^{[3]}(z^{[3]}$)$\rightarrow$ 3층에 대한 활성화 계산

# %% [markdown]
# ###**<심층 신경망의 4층>**

# %% [markdown]
# - - -

# %% [markdown]
# ![12345678.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *  $z^{[4]}$ = $W^{[4]}$$a^{[3]}$+$b^{[4]}$ $\rightarrow$ $W^{[4]}$ 과$b^{[4]}$은 층 2에서 활성화에 영향을 주는 파라미터
#
#
# * $a^{[4]}$= $g^{[4]}(z^{[4]}$)$\rightarrow$ 4층에 대한 활성화 계산

# %% [markdown]
# ###**<일반적인  Forward propagation 수식>**

# %% [markdown]
#  * $z^{[l]}$=$W^{[l]}$$a^{[l-1]}$+$b^{[l]}$
#  * $a^{[l]}$= $g^{[l]}(z^{[l]}$)

# %% [markdown]
# ##**학습 세트에 대한 벡터화된 방법**

# %% [markdown]
# - - -

# %% [markdown]
#   ${\color{Red} f}$ ${\color{Red}o}$ ${\color{Red}r}$
#
#   ${\color{Red} l}$ ${\color{Red}=}$ ${\color{Red}1}$
#   ${\color{Red} .}$ ${\color{Red}.}$ ${\color{Red}.}$
#   ${\color{Red} 4}$
#
#  **{** $Z^{[l]}$=$W^{[l]}$$A^{[l-1]}$+$b^{[l]}$
#    $A^{[l]}$= $g^{[l]}(Z^{[l]}$)
#
#    $Z^{[1]}$ = $W^{[1]}$$A^{[0]}$+$b^{[1]}$
#
#
#   $A^{[1]}$= $g^{[1]}(Z^{[1]}$)
#
#    $Z^{[2]}$ = $W^{[2]}$$A^{[1]}$+$b^{[2]}$
#
#   $A^{[2]}$= $g^{[2]}(Z^{[2]}$)
#
#    $Z^{[3]}$ = $W^{[3]}$$A^{[2]}$+$b^{[3]}$
#
#   $A^{[3]}$= $g^{[3]}(Z^{[3]}$)
#
#    $Z^{[4]}$ = $W^{[4]}$$A^{[3]}$+$b^{[4]}$
#
#
#   $A^{[4]}$= $g^{[4]}(Z^{[4]}$) **}**

# %% [markdown]
# * 반복문을 쓰는이유는?
#
#  **1** 에서 **L** 까지의 **l** 에 대해
# 각각의 층에 대해 활성화를 계산해야 하기 때문

# %% [markdown]
# ##**코드를 디버깅할때 TIP**

# %% [markdown]
# - - -

# %% [markdown]
# 행렬의 차원을 자세하게 생각하는과정을 거치자!
