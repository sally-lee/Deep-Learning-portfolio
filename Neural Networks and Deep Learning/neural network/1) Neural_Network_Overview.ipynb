# %% [markdown]
# # Neural Network Overview

# %% [markdown]
# ## 학습목표
# Neural Network을 어떻게 구현하는지에 대한 개요

# %% [markdown]
# ## Preview
# * logistic regression

# %% [markdown]
# <p align="center"> <img src="images/logistic1.PNG" height="100px" width="300px"></p>

# %% [markdown]
# <center><font color='black'><b>Figure 1</b>: logistic regression model</font></center>

# %% [markdown]
# ![logistic2-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure2. compute $z$

# %% [markdown]
# ### 1. feature $x$와 parameter $w, b$를 입력하면 $z$를 계산

# %% [markdown]
# ![logistic2-2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure3. compute $a$

# %% [markdown]
# ### 2. $z$는 $\hat{y}$이라고 썼던 $a$를 계산

# %% [markdown]
# ![logistic1-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure4. $\hat{y}=a$

# %% [markdown]
# ![logistic2-3.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure4.1 compute $L$

# %% [markdown]
# ### 3. 손실함수 $L$ 을 계산

# %% [markdown]
# ---

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# ![nn1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure5. neural network
# > sigmoid unit을 쌓아서 만들 수 있다.

# %% [markdown]
# ![nn4-1.PNG](data:image/png;base64,...)

# %% [markdown]
#  Figure6. compute $z^{[1]}$

# %% [markdown]
# ### 1. feature $x$와 parameter $w, b$를 입력하면 $z^{[1]}$를 계산

# %% [markdown]
# ![nn3.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure7. layer $[1],[2]$

# %% [markdown]
# * $x^{[i]}$ : i번째 layer
# * $x^{(i)}$ : i번째 trainning sample

# %% [markdown]
# ![nn4-2.PNG](data:image/png;base64,...)

# %% [markdown]
#  Figure8. compute $a^{[1]}$

# %% [markdown]
#  ### 2. $\sigma (z^{[1]})$ 인 $a^{[1]}$을 계산

# %% [markdown]
# ![nn4-3.PNG](data:image/png;base64,...)

# %% [markdown]
#  Figure9. compute $z^{[2]}$

# %% [markdown]
# ### 3. 다른 선형식을 사용하여 $z^{[2]}$를 계산

# %% [markdown]
# ![nn4-4.PNG](data:image/png;base64,...)

# %% [markdown]
#  Figure10. compute $a^{[2]}$

# %% [markdown]
# ### 4. $\hat{y}$과 같은 neural network의 최종 출력값인 $a^{[2]}$를 계산

# %% [markdown]
# ![neuralnetworks2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure11. $\hat{y}=a^{[2]}$

# %% [markdown]
# ## logistic regression와 Neural Network의 차이

# %% [markdown]
# ### 1. $z, a$ 계산 횟수
# - logistic regression : $z, a$를 계산하는 2 step (Figure2,3)
# - Neural Network : $z, a$를 여러번 계산 (Figure7,8 and Figure9,10)

# %% [markdown]
# ### 2. backpropagation

# %% [markdown]
# #### logistic regression : $dz,da$ 계산

# %% [markdown]
# ![logistic-back.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure10. compute $dz, da$

# %% [markdown]
# #### Neural Network : $da^{[2]} , dz^{[2]}, dW^{[2]}, db^{[2]} $ 계산

# %% [markdown]
# ![nn-back1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure11. compute $da^{[2]}$

# %% [markdown]
# 1. $da^{[2]}$ 계산

# %% [markdown]
# ![nn-back2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure12. compute $ dz^{[2]} $

# %% [markdown]
# 2. $ dz^{[2]} $ 계산

# %% [markdown]
# ![nn-back3.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure13. compute $ dW^{[2]}, db^{[2]} $

# %% [markdown]
# 3. $da^{[2]} , dz^{[2]} $를 가지고 $ dW^{[2]}, db^{[2]} $ 계산

# %% [markdown]
# ---
# # 참고
# [Andrew Ng-Neural Network Overview](https://www.youtube.com/watch?v=CcRkHl75Z-Y&list=PLkDaE6sCZn6Ec-XTbcX1uRg2_u4xOEky0&index=25)
