# %% [markdown]
# # Computing Neural Network Output

# %% [markdown]
# ## 학습목표
# -  neural Network이 정확히 어떻게 출력값을 계산하는지 확인
# - logistic regression과 비슷하지만 여러번 반복

# %% [markdown]
# ## preview
# - logistic regression

# %% [markdown]
# <center>
#
# ![loginode1.PNG](data:image/png;base64,...)</center>

# %% [markdown]
# <center>Figure1.logistic regression model</center>

# %% [markdown]
# 1. $z = w^Tx+b$
# 2. $a = \sigma(z)$
#
# 이 원은 $z$를 계산하고 활성화 $a$를 $\sigma(z)$로 계산하는 2 step 계산을 나타낸다.

# %% [markdown]
# ## neural network representation
# * 위 2 step을 많이 반복한다.
#
# 은닉층의 노드 하나를 집중해서 자세히 살펴본다.

# %% [markdown]
# <center>
#
# ![3.nn1-1.PNG](data:image/png;base64,...)

# %% [markdown]
# <center>Figure2.$z^{[1]}$ of node1

# %% [markdown]
# ### 1. 노드의 왼쪽이라 생각하고 $z=w^Tx+b$를 계산한다.
# > 이 값들은 모두 첫번째 은닉층과 관련됐기 때문에 모두 윗첨자 [1]을 붙여준다.
# > 은닉층의 첫번째 노드이기 때문에 아래첨자 1도 붙여준다.

# %% [markdown]
# ![3.nn1-2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure3. a of node1

# %% [markdown]
# ### 2. $a_1^{[1]}=\sigma(z_1^{[1]})$을 계산한다.
#
# * 신경망의 노드인 원은 이 2 step을 의미

# %% [markdown]
# ![3.nn2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure4. $z_2^{[1]},a$ of node2

# %% [markdown]
# ### 3. 두번째 노드도 1,2 step과 같이 계산한다.

# %% [markdown]
# ### 4. 나머지 두 노드도 비슷한 계산을 한다.
#
# * $a_i^{[l]}$ <br>
# > $l$ : layer <br>
# > $i$ : node in layer

# %% [markdown]
# ## 노드들에 대한 식

# %% [markdown]
# ![3_식1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure5. 노드식

# %% [markdown]
# > $w_1^{[1]T} = (w_1^{[1]})^T$
#
# * for 문을 써서 구현하면 비효율적 → **vectorization**

# %% [markdown]
# ### 1. compute $z$ as vector

# %% [markdown]
# #### 1) $w$를 행렬처럼 쌓으면 열벡터의 전치인 $(4,3)$이 된다.

# %% [markdown]
# ![3_식1-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure6. $w$

# %% [markdown]
# ![3_식1-2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure7. column vector의 전치

# %% [markdown]
# #### 2) feature $x_1,x_2,x_3$과 곱하면

# %% [markdown]
# ![3_식1-3.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure8. $w^{[1]}$ and feature $x$

# %% [markdown]
# #### 3) dot 연산에 의해 다음과 같이 얻는다.

# %% [markdown]
# ![3_식1-4.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure9. dot연산한 $w^{[1]}$ and feature $x$

# %% [markdown]
# #### 4) $b$를 더해주면 결과의 각 행은 위에서 계산한 네 값과 정확히 일치한다.

# %% [markdown]
# ![3_식1-6.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure10.vectorizaion output

# %% [markdown]
# ![3_식1-7.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure11.식

# %% [markdown]
# #### 5) 따라서 이 값은 $ z_1^{[1]}, z_2^{[1]}, z_3^{[1]}, z_4^{[1]}$과 같다.

# %% [markdown]
# ![3_식1-8.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure12. $ z_1^{[1]}, z_2^{[1]}, z_3^{[1]}, z_4^{[1]}$

# %% [markdown]
# * $Z^{[1]}$ : 각 $z$를 열벡터로 쌓은 벡터

# %% [markdown]
# ![3_식1-9.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure13. $ Z^{[1]}$

# %% [markdown]
# * $W^{[1]}$ : $w$를 쌓아서 만든 (4, 3) 행렬
# * $b^{[1]}$ : $b$를 쌓아서 만든 (4, 1) 행렬

# %% [markdown]
# ![3_식1-10.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure14. $ W^{[1]}, b^{[1]}$

# %% [markdown]
# ### 2. compute $a$

# %% [markdown]
# #### 1) $a^{[1]}$ : $a_1^{[1]}$부터 $a_4^{[1]}$을 stack한 벡터

# %% [markdown]
# ![3_식2-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure15.$a^{[1]}$

# %% [markdown]
# ![3_식2-2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure16.$a^{[1]}$

# %% [markdown]
# #### 2) $\sigma(Z^{[1]})$와 같다.

# %% [markdown]
# ![3_식2-3.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure17.$\sigma(Z^{[1]})$

# %% [markdown]
# * $\sigma$ : $Z^{[1]}$의 각 원소들의 sigmoid 값을 계산하는 함수

# %% [markdown]
# ## 노드들에 대한 shape

# %% [markdown]
# ![3_식3-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure18.2NN

# %% [markdown]
# ![3_식3-2.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure19.Given input x

# %% [markdown]
# ### 1. $z^{[1]}=W^{[1]}x+b^{[1]}$
# >  $z^{[1]} : (4,1)$<br>
# >  $W^{[1]} : (4,3)$<br>
# >  $x : (3,1) $ :
# >> $a^{[0]}$ (feature x의 가명) $=x$, $a^{[2]}=\hat{y}$

# %% [markdown]
# ![3_식3-3.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure19.1

# %% [markdown]
# ### 2. $a^{[1]}=\sigma (z^{[1]})$
# >  $a^{[1]} : (4,1)$<br>
# >  $z^{[1]} : (4,1)$<br>

# %% [markdown]
# ![3_식3-4.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure19.2

# %% [markdown]
# ![3_식3-4-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure19.3

# %% [markdown]
# ### 3. $z^{[2]}=W^{[2]}a^{[1]}+b^{[2]}$
# >  $W^{[2]} : (1,4)$<br>
# >  $a^{[1]} : (4,1)$<br>
# >  $b^{[2]} : (1,1)$<br>
# >  $z^{[2]} : (1,1)$<br>

# %% [markdown]
# ![3_식3-5.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure19.3

# %% [markdown]
# ### 4. $a^{[2]}=\sigma (z^{[2]})$
# >  $a^{[2]} : (1,1)$<br>
# >  $z^{[2]} : (1,1)$<br>

# %% [markdown]
# ![3_식3-6.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure19.4

# %% [markdown]
# * 마지막 출력 유닛을 parameter $w,b$를 가지는 logistic regression과 비슷하게 생각하면 $w,b$대신에 $(1,4)$차원 $W^{[2]}$과 $(1,1)$차원 $b^{[2]}$를 쓰는것을 제외하면 <br>
# $w^{T}=W^{[2]}$, $b=b^{[2]}$와 비슷하다.

# %% [markdown]
# ![3_식4.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure20.

# %% [markdown]
# # 정리
# * $z=w^{T}x+b$
# * $\hat{y}=a=\sigma(z)$ 계산<br>

# %% [markdown]
# * 은닉층 : 1개인 신경망에서는 Figure21.을 구현

# %% [markdown]
# ![3_식5.PNG](data:image/png;base64,...)

# %% [markdown]
# Figure21.

# %% [markdown]
# 1. 은닉층의 logistic regression 노드들의 출력값 계산
# 2. 출력층의 logistic regression 노드의 출력값 계산

# %% [markdown]
# ---
# # 참고
# [Andrew Ng-Computing Neural Network Output]([https://www.youtube.com/watch?v=rMOdrD61IoU&list=PLkDaE6sCZn6Ec-XTbcX1uRg2_u4xOEky0&index=27)
