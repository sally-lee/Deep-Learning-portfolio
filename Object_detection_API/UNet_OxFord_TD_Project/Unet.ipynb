# %% [markdown]
# # AI 기반 Remove Background Images Tool

# %% [markdown]
# ## 0. Google Drive Mount

# %% [markdown]
# ### 사전 준비

# %%
from google.colab import drive
drive.mount('/content/google_drive')
# Out:
# Drive already mounted at /content/google_drive; to attempt to forcibly remount, call drive.mount("/content/google_drive", force_remount=True).

# %%
# %cd /content
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !cp -r "/content/google_drive/MyDrive/Tensorflow_OD_API/unet_oxford/UNet_OxFord_TD_Project/" ./

# %%
# %cd /content/UNet_OxFord_TD_Project
# Out:
# /content/UNet_OxFord_TD_Project

# %%
# !pwd
# Out:
# /content/UNet_OxFord_TD_Project

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_Projects/UNet_OxFord_TD_Project/model.h5" ./

# %%
# !ls -al
# Out:
# total 1600
# drwx------ 2 root root    4096 Dec  2 07:48 .
# drwxr-xr-x 1 root root    4096 Dec  2 07:48 ..
# -rw------- 1 root root    2761 Dec  2 07:48 data.py
# -rw------- 1 root root     968 Dec  2 07:48 display.py
# -rw------- 1 root root     448 Dec  2 07:48 inftest.py
# -rw------- 1 root root    2507 Dec  2 07:48 model.py
# -rw------- 1 root root     891 Dec  2 07:48 remove.py
# -rw------- 1 root root    1469 Dec  2 07:48 train.py
# -rw------- 1 root root 1604666 Dec  2 07:48 Unet.ipynb

# %%
# %cd /content
# Out:
# /content

# %%
import sys
sys.path.append("/content/UNet_OxFord_TD_Project")

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.8/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/UNet_OxFord_TD_Project']

# %% [markdown]
# ### Change Directory

# %%
# %cd /content/UNet_OxFord_TD_Project
# %matplotlib inline
# Out:
# /content/UNet_OxFord_TD_Project

# %% [markdown]
# ## 1. Import Modules

# %%
# !pwd
# Out:
# /content/UNet_OxFord_TD_Project

# %%
# !mkdir dataset

# %%
# %cd ./dataset
# Out:
# /content/UNet_OxFord_TD_Project/dataset

# %%
# !tar -xvf /content/google_drive/MyDrive/Tensorflow_OD_API/efficientdet/images.tar.gz
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# images/american_bulldog_194.jpg
# images/Birman_175.jpg
# images/american_bulldog_178.jpg
# images/staffordshire_bull_terrier_93.jpg
# images/Egyptian_Mau_58.jpg
# images/havanese_44.jpg
# images/english_cocker_spaniel_97.jpg
# images/Ragdoll_111.jpg
# images/american_pit_bull_terrier_159.jpg
# images/english_setter_134.jpg
# images/english_setter_87.jpg
# images/wheaten_terrier_198.jpg
# images/pug_180.jpg
# images/boxer_172.jpg
# images/Sphynx_197.jpg
# images/german_shorthaired_2.jpg
# images/British_Shorthair_9.jpg
# images/pug_89.jpg
# images/japanese_chin_39.jpg
# images/Ragdoll_20.jpg
# images/american_bulldog_111.jpg
# images/yorkshire_terrier_112.jpg
# images/Persian_88.jpg
# images/pug_9.jpg
# images/Birman_40.jpg
# images/British_Shorthair_272.jpg
# images/havanese_7.jpg
# images/pomeranian_154.jpg
# images/beagle_49.jpg
# images/British_Shorthair_94.jpg
# images/Persian_90.jpg
# images/staffordshire_bull_terrier_30.jpg
# ...

# %%
# !tar -xvf /content/google_drive/MyDrive/Tensorflow_OD_API/efficientdet/annotations.tar.gz
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# annotations/trimaps/._pomeranian_180.png
# annotations/trimaps/pomeranian_180.png
# annotations/trimaps/._pomeranian_181.png
# annotations/trimaps/pomeranian_181.png
# annotations/trimaps/._pomeranian_182.png
# annotations/trimaps/pomeranian_182.png
# annotations/trimaps/._pomeranian_183.png
# annotations/trimaps/pomeranian_183.png
# annotations/trimaps/._pomeranian_184.png
# annotations/trimaps/pomeranian_184.png
# annotations/trimaps/._pomeranian_185.png
# annotations/trimaps/pomeranian_185.png
# annotations/trimaps/._pomeranian_186.png
# annotations/trimaps/pomeranian_186.png
# annotations/trimaps/._pomeranian_187.png
# annotations/trimaps/pomeranian_187.png
# annotations/trimaps/._pomeranian_188.png
# annotations/trimaps/pomeranian_188.png
# annotations/trimaps/._pomeranian_189.png
# annotations/trimaps/pomeranian_189.png
# annotations/trimaps/._pomeranian_19.png
# annotations/trimaps/pomeranian_19.png
# ...

# %%
# %cd /content/UNet_OxFord_TD_Project
# Out:
# /content/UNet_OxFord_TD_Project

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import random

# %%
from inftest import inference_test
from train import train
from data import load_data, tf_dataset
from remove import remove
from display import display, show_predictions

# %%
# !pwd
# Out:
# /content/UNet_OxFord_TD_Project

# %% [markdown]
# ## 2. Train model

# %%
# !pwd
# Out:
# /content/UNet_OxFord_TD_Project/dataset

# %%
train()
# Out:
# Epoch 1/40
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-45-2da0ffaf5447> in <module>
# ----> 1 train()
#
# /content/UNet_OxFord_TD_Project/train.py in train()
#      40     ]
#      41
# ---> 42     model_history = unet.fit(train_dataset, steps_per_epoch=train_steps, validation_data=valid_dataset,
#      43                              validation_steps=valid_steps, epochs=epochs, callbacks=callbacks)
#      44
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ...

# %% [markdown]
# ## 3. Test model

# %%
inference_test()
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
