# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import matplotlib as mpl

# 유니코드 깨짐현상 해결
mpl.rcParams['axes.unicode_minus'] = False

# 나눔고딕 폰트 적용
plt.rcParams["font.family"] = 'NanumGothic'

# 경고 무시
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train =   pd.read_excel('/content/drive/MyDrive/2차입찰금액 예측모델/dataset/2002_2021 최종.xlsx')

# %%
from sklearn.model_selection import train_test_split
x = train[['기초금액', '추정가격', '예가범위', '낙차하한율']]
y = train[['입찰금액']]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y ,test_size=0.1)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor = KNeighborsRegressor(n_neighbors = 3, weights = "distance")
regressor.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3, weights='distance')

# %%
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999699197738011
# 0.9997806755946458

# %%
regressor = KNeighborsRegressor(n_neighbors = 3, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9991646919113728
# 0.9997697681000465

# %%
regressor = KNeighborsRegressor(n_neighbors = 4, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9982319647541255
# 0.9997838179806641

# %%
regressor = KNeighborsRegressor(n_neighbors = 5, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.997463912709171
# 0.9997543017792707

# %%
regressor = KNeighborsRegressor(n_neighbors = 6, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9968786203738872
# 0.9997107450439282

# %%
regressor = KNeighborsRegressor(n_neighbors = 7, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.996395599749348
# 0.9996952438275204

# %%
regressor = KNeighborsRegressor(n_neighbors = 8, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9959881247444926
# 0.999662114957777

# %%
regressor = KNeighborsRegressor(n_neighbors = 9, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9956683856801216
# 0.9996254165106735

# %%
regressor = KNeighborsRegressor(n_neighbors = 10, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9953948024448829
# 0.9996081245668369

# %%
regressor = KNeighborsRegressor(n_neighbors = 11, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9951142360254351
# 0.9995808434980843

# %%
regressor = KNeighborsRegressor(n_neighbors = 12, weights = "uniform")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9948904243647179
# 0.9995521120521395

# %%
regressor = KNeighborsRegressor(n_neighbors = 4, weights = "distance")
regressor.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4, weights='distance')

# %%
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999690631472965
# 0.9997880833878395

# %%
regressor = KNeighborsRegressor(n_neighbors = 5, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999676789769558
# 0.9997718577730313

# %%
regressor = KNeighborsRegressor(n_neighbors = 6, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999663929197129
# 0.9997516562092641

# %%
regressor = KNeighborsRegressor(n_neighbors = 7, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999696963777622
# 0.9997540692520759

# %%
regressor = KNeighborsRegressor(n_neighbors = 8, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999697689925662
# 0.99974224360889

# %%
regressor = KNeighborsRegressor(n_neighbors = 9, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999699954790648
# 0.9997190815858403

# %%
regressor = KNeighborsRegressor(n_neighbors = 10, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999699966168933
# 0.9997086238510696

# %%
regressor = KNeighborsRegressor(n_neighbors =11, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999699979600779
# 0.9996941895530718

# %%
regressor = KNeighborsRegressor(n_neighbors = 12, weights = "distance")
regressor.fit(X_train,y_train)
print(regressor.score(X_train,y_train))
 
print(regressor.score(X_test,y_test))
# Out:
# 0.9999699994432119
# 0.9996770433496228

# %%
import pickle 

# knn = NearestNeighbors(10)
# knn.fit(my_data)

# Its important to use binary mode 
knnPickle = open('knnpickle_file', 'wb') 
      
# source, destination 
pickle.dump(regressor, knnPickle)  

# close the file
knnPickle.close()
                
      
# load the model from disk
loaded_model = pickle.load(open('knnpickle_file', 'rb'))
result = loaded_model.predict(X_test)

# %%
train =   pd.read_excel('/content/drive/MyDrive/입찰금액 예측모델/dataset/2023.xlsx')

# %%
from sklearn.model_selection import train_test_split
unknown = train[['기초금액', '추정가격', '예가범위', '낙찰하한율']]

# %%
guesses=regressor.predict(unknown)

# %%
print(guesses)
# Out:
# [[1.76703886e+08]
#  [5.88423353e+07]
#  [1.10455336e+08]
#  ...
#  [5.51758705e+07]
#  [3.47381358e+07]
#  [2.93580177e+07]]

# %% [markdown]
# 99.96

# %%
print(guesses[0])
# Out:
# [1.76703886e+08]

# %% [markdown]
# 99.98

# %%
print(guesses[1])
# Out:
# [58842335.26701554]

# %%
print(guesses[2])
# Out:
# [1.10455336e+08]

# %% [markdown]
# 99.2

# %%
print(guesses[3])
# Out:
# [1.92981788e+08]

# %% [markdown]
# 99.5

# %%
print(guesses[4])
# Out:
# [1.05004599e+08]

# %%
print(guesses[5])
# Out:
# [1.05004599e+08]

# %%
print(guesses[6])
# Out:
# [1.05004599e+08]

# %% [markdown]
# 99.9

# %%
print(guesses[7])
# Out:
# [93164852.91756637]

# %% [markdown]
# 99.6

# %%
print(guesses[8])
# Out:
# [2.15423209e+08]

# %%
print(guesses[9])
# Out:
# [99386446.92481892]

# %%
print(guesses[10])
# Out:
# [56860743.43489745]

# %%
print(guesses[7])
# Out:
# [93164852.91756637]

# %%
print(guesses[8])
# Out:
# [2.15423209e+08]

# %%
print(guesses[9])
# Out:
# [99386446.92481892]

# %%
print(guesses[10])
# Out:
# [56860743.43489745]

# %%
print(guesses[11])
# Out:
# [15257118.22634228]

# %%
print(guesses[12])
print(guesses[13])
print(guesses[14])
print(guesses[15])
# Out:
# [54593449.6387233]
# [87157906.79051735]
# [1.43280475e+08]
# [34906417.57000001]

# %%
print(guesses[16])
print(guesses[17])
print(guesses[18])
print(guesses[19])
# Out:
# [1.75349351e+08]
# [1.52604987e+08]
# [1.39466468e+08]
# [3.9524372e+08]

# %%
print(guesses[20])
print(guesses[21])
print(guesses[22])
print(guesses[23])
# Out:
# [22366070.8832927]
# [91676927.08091612]
# [2.60776385e+08]
# [2.22660575e+09]
