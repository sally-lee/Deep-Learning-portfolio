# %% [markdown]
# #svm은 데이터가 linear할때 유용하고 svr 비선형 일때 유용하다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import matplotlib as mpl

# 유니코드 깨짐현상 해결
mpl.rcParams['axes.unicode_minus'] = False

# 나눔고딕 폰트 적용
plt.rcParams["font.family"] = 'NanumGothic'

# 경고 무시
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train =   pd.read_excel('/content/drive/MyDrive/2차입찰금액 예측모델/dataset/2002_2021 최종.xlsx')

# %%
train.columns
# Out:
# Index(['기초금액', '추정가격', '예정가격', '낙차하한율', '사정율', '예가범위', '입찰금액'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x = train[['기초금액', '추정가격', '낙차하한율','예가범위']]
y = train[['입찰금액']]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y ,test_size=0.1)

# %%
from sklearn.svm import SVR

svm_poly_reg=SVR(kernel='poly',degree=2,C=100,epsilon=0.1)
svm_poly_reg.fit(X_train,y_train)

# %%
score = svm_poly_reg.evaluate(X_test, y_test)

# %% [markdown]
# test loss

# %%
print(score[0])

# %% [markdown]
# test accuracy

# %%
print(score[1])

# %%
print(svm_poly_reg.score(X_train,y_train))
print(svm_poly_reg.score(X_test,y_test))
